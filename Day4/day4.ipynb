# %%
x = 5
for i in x:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 x = 5
# ----> 2 for i in x:
#       3     print(i)
#
# TypeError: 'int' object is not iterable
